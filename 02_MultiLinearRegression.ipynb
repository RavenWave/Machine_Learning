# %%
# y = b0 + (b1 * X1) + (b2 * X2) + (b3 * X3) .. + .. (bn * Xn)

# %% [markdown]
# # **1. Import Basic Libraries**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as stats
plt.rcParams["figure.figsize"] = (8, 4)

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# # **2. Read Data Set**

# %%
df = pd.read_csv('DATASETS/Advertising.csv')
df.head()
# Out:
#       TV  radio  newspaper  sales
# 0  230.1   37.8       69.2   22.1
# 1   44.5   39.3       45.1   10.4
# 2   17.2   45.9       69.3    9.3
# 3  151.5   41.3       58.5   18.5
# 4  180.8   10.8       58.4   12.9

# %% [markdown]
# ## **Data Preparation - EDA**

# %%
import missingno as msno # we can inspect missings

# %%
msno.matrix(df); # there's no missings

# %%
from summarytools import dfSummary

# %%
dfSummary(df)
# Out:
# <style type="text/css">
# #T_b9196 thead>tr>th {
#   text-align: left;
# }
# #T_b9196_row0_col0, #T_b9196_row1_col0, #T_b9196_row2_col0, #T_b9196_row3_col0 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 5%;
#   max-width: 50px;
#   min-width: 20px;
# }
# #T_b9196_row0_col1, #T_b9196_row1_col1, #T_b9196_row2_col1, #T_b9196_row3_col1 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 15%;
#   max-width: 200px;
#   min-width: 100px;
#   word-break: break-word;
# }
# #T_b9196_row0_col2, #T_b9196_row1_col2, #T_b9196_row2_col2, #T_b9196_row3_col2 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 30%;
#   min-width: 100px;
# }
# #T_b9196_row0_col3, #T_b9196_row1_col3, #T_b9196_row2_col3, #T_b9196_row3_col3 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 25%;
#   min-width: 100px;
# }
# ...

# %%
from scipy.stats import skew

# %%
skew(df['TV'])
# Out:
# -0.06932836662244649

# %%
skew(df['radio'])
# Out:
# 0.0934668451108453

# %%
skew(df['newspaper'])
# Out:
# 0.8879959753085498

# %% [markdown]
# > **Skewness values between -0.5 and +0.5 are accepted symmetrically roughly. Zero (0) is perfect symmetrically.**

# %%
for j in df.drop(columns = "sales").columns:   
    g = sns.distplot(df[j], color= "b", label= "Skewness : %.2f"%(df[j].skew()))   
    g = g.legend(loc= "best")   
    plt.show()

# %%
from ydata_profiling import ProfileReport

# %%
ProfileReport(df)
# Out:
# ...
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# <iframe width="100%" height="800px" srcdoc="&lt;!doctype html&gt;&lt;html lang=en&gt;&lt;head&gt;&lt;meta charset=utf-8&gt;&lt;meta name=viewport content=&quot;width=device-width, initial-scale=1, shrink-to-fit=no&quot;&gt;&lt;meta name=description content=&quot;Profile report generated by YData! Visit us at https://ydata.ai&quot;&gt;&lt;meta name=author content=&quot;YData and the open source community.&quot;&gt;&lt;meta name=generator content=&quot;Pandas Profiling vv4.9.0&quot;&gt;&lt;meta name=url content=https://github.com/ydataai/ydata-profiling&gt;&lt;meta name=date content=&quot;2024-08-26 21:41:56.779656&quot;&gt;&lt;title&gt;Pandas Profiling Report&lt;/title&gt;&lt;style&gt;
# /*!
#  * Bootstrap v3.3.7 (http://getbootstrap.com)
#  * Copyright 2011-2016 Twitter, Inc.
#  * Licensed under MIT (https://github.com/twbs/bootstrap/blob/master/LICENSE)
# ...

# %% [markdown]
# # **3. Train-Test Split**

# %%
X = df.drop(columns='sales')
y = df['sales']

# %%
X.head()
# Out:
#       TV  radio  newspaper
# 0  230.1   37.8       69.2
# 1   44.5   39.3       45.1
# 2   17.2   45.9       69.3
# 3  151.5   41.3       58.5
# 4  180.8   10.8       58.4

# %%
y.head()
# Out:
# 0    22.1
# 1    10.4
# 2     9.3
# 3    18.5
# 4    12.9
# Name: sales, dtype: float64

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.3, random_state=42)

# %%
print("X Train features shape: {}\ny Train features shape: {}\nX Test features shape : {}\nY Test features shape : {}".format(X_train.shape, y_train.shape, X_test.shape, y_test.shape))
# Out:
# X Train features shape: (140, 3)
# y Train features shape: (140,)
# X Test features shape : (60, 3)
# Y Test features shape : (60,)

# %%
X_train.head()
# Out:
#         TV  radio  newspaper
# 169  284.3   10.6        6.4
# 97   184.9   21.0       22.0
# 31   112.9   17.4       38.6
# 12    23.8   35.1       65.9
# 35   290.7    4.1        8.5

# %%
y_train.head()
# Out:
# 169    15.0
# 97     15.5
# 31     11.9
# 12      9.2
# 35     12.8
# Name: sales, dtype: float64

# %% [markdown]
# # **4. Model Fitting and Compare Actual and Predicted Labels**

# %%
from sklearn.linear_model import LinearRegression

# %%
model = LinearRegression()

# %%
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(X_test)
y_pred
# Out:
# array([16.5653963 , 21.18822792, 21.55107058, 10.88923816, 22.20231988,
#        13.35556872, 21.19692502,  7.35028523, 13.27547079, 15.12449511,
#         9.01443026,  6.52542825, 14.30205991,  8.97026042,  9.45679576,
#        12.00454351,  8.91549403, 16.15619251, 10.29582883, 18.72473553,
#        19.76821818, 13.77469028, 12.49638908, 21.53501762,  7.60860741,
#         5.6119801 , 20.91759483, 11.80627665,  9.08076637,  8.51412012,
#        12.17604891,  9.9691939 , 21.73008956, 12.77770578, 18.1011362 ,
#        20.07590796, 14.26202556, 20.93826535, 10.83938827,  4.38190607,
#         9.51332406, 12.40486324, 10.17045434,  8.09081363, 13.16388427,
#         5.2243552 ,  9.28893833, 14.09330719,  8.69024497, 11.66119763,
#        15.71848432, 11.63156862, 13.35360735, 11.1531472 ,  6.33636845,
#         9.76157954,  9.4195714 , 24.25516546,  7.69519137, 12.15317572])

# %%
coefs = model.coef_ # coefficients of features
coefs
# Out:
# array([0.04405928, 0.1992875 , 0.00688245])

# %%
model.feature_names_in_
# Out:
# array(['TV', 'radio', 'newspaper'], dtype=object)

# %%
intercept = model.intercept_
intercept
# Out:
# 2.70894909251591

# %%
X_test.loc[95]
# Out:
# TV           163.3
# radio         31.6
# newspaper     52.9
# Name: 95, dtype: float64

# %%
x1, x2, x3 = X_test.loc[95]

# %%
y_pred_95 = x1 * coefs[0] + x2 * coefs[1] + x3 * coefs[2] + intercept
y_pred_95
# Out:
# 16.565396297434837

# %%
my_dict = {"Actual": y_test, "pred": y_pred, "residual": y_test - y_pred}

# %%
comparing = pd.DataFrame(my_dict)
comparing
# Out:
#      Actual       pred  residual
# 95     16.9  16.565396  0.334604
# 15     22.4  21.188228  1.211772
# 30     21.4  21.551071 -0.151071
# 158     7.3  10.889238 -3.589238
# 128    24.7  22.202320  2.497680
# 115    12.6  13.355569 -0.755569
# 69     22.3  21.196925  1.103075
# 170     8.4   7.350285  1.049715
# 174    11.5  13.275471 -1.775471
# 45     14.9  15.124495 -0.224495
# 66      9.5   9.014430  0.485570
# 182     8.7   6.525428  2.174572
# 165    11.9  14.302060 -2.402060
# 78      5.3   8.970260 -3.670260
# 186    10.3   9.456796  0.843204
# 177    11.7  12.004544 -0.304544
# 56      5.5   8.915494 -3.415494
# 152    16.6  16.156193  0.443807
# 82     11.3  10.295829  1.004171
# 68     18.9  18.724736  0.175264
# 124    19.7  19.768218 -0.068218
# 16     12.5  13.774690 -1.274690
# 148    10.9  12.496389 -1.596389
# 93     22.2  21.535018  0.664982
# 65      9.3   7.608607  1.691393
# 60      8.1   5.611980  2.488020
# 84     21.7  20.917595  0.782405
# ...

# %% [markdown]
# # **5. Error Metrics**

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# %%
R2_score = r2_score(y_test, y_pred)
R2_score
# Out:
# 0.8609466508230368

# %%
mae = mean_absolute_error(y_test, y_pred)
mae
# Out:
# 1.5116692224549084

# %%
mse = mean_squared_error(y_test, y_pred)
mse
# Out:
# 3.79679723671522

# %%
rmse = np.sqrt(mean_squared_error(y_test, y_pred))
rmse
# Out:
# 1.9485372043446387

# %% [markdown]
# # **6. Evaluation Model**

# %%
def eval_metric(actual, pred):
    mae = mean_absolute_error(actual, pred)
    mse = mean_squared_error(actual, pred)
    rmse = np.sqrt(mean_squared_error(actual, pred))
    R2_score = r2_score(actual, pred)
    
    print("Model testing performance: ")
    print("---------------------------")
    print(f"R2_score \t: {round(R2_score, 2)}")
    print(f"MAE \t\t: {round(mae, 2)}")
    print(f"MSE \t\t: {round(mse, 2)}")
    print(f"RMSE \t\t: {round(rmse, 2)}")

# %%
print('For Test Data:\n')
eval_metric(y_test, y_pred)
# Out:
# For Test Data:
#
# Model testing performance:
# ---------------------------
# R2_score 	: 0.86
# MAE 		: 1.51
# MSE 		: 3.8
# RMSE 		: 1.95

# %%
y_train_pred = model.predict(X_train)

# %%
print('For Train Data:\n')
eval_metric(y_train, y_train_pred)
# Out:
# For Train Data:
#
# Model testing performance:
# ---------------------------
# R2_score 	: 0.91
# MAE 		: 1.16
# MSE 		: 2.48
# RMSE 		: 1.57

# %% [markdown]
# # **7. Pllotting Residual**

# %%
residuals = y_test - y_pred

# %%
plt.figure(figsize=(10, 6))

sns.scatterplot(x=y_test, y=residuals)
plt.xlabel('Sales')
plt.ylabel('Residuals')
plt.axhline(y=0, color='r', linestyle='--')
plt.show()

# %% [markdown]
# > Our distribution of residuals is normal. If we see any pattern at the above graph, it means this data set not proper for linear regression. Because the pattern indicates a systemically errors.

# %%
# to see distribution of residuals: 
sns.kdeplot(residuals);

# %%
# the harmony of between data set and residuals:
stats.probplot(residuals, dist='norm', plot=plt);

# %% [markdown]
# > We generally use below graph instead of above graphs:

# %%
from yellowbrick.regressor import ResidualsPlot

# %%
# instantiate the linear model and visualizer
model = LinearRegression()
visualizer = ResidualsPlot(model)

visualizer.fit(X_train, y_train) # Fit the training data to the visualizer
visualizer.score(X_test, y_test) # Evaluate the model on the test data
visualizer.show();

# %% [markdown]
# > overfitting control:

# %%
from yellowbrick.regressor import PredictionError

model = LinearRegression()
visualizer = PredictionError(model)

visualizer.fit(X_train, y_train) # Fit the training data to the visualizer
visualizer.score(X_test, y_test) # Evaluate the model on the test data
visualizer.show();

# %% [markdown]
# # **8. Final Model**

# %%
final_model = LinearRegression()
final_model.fit(X, y)
# Out:
# LinearRegression()

# %%
coeff_df = pd.DataFrame(final_model.coef_, index=X.columns, columns=['Coefficient'])
coeff_df
# Out:
#            Coefficient
# TV            0.045765
# radio         0.188530
# newspaper    -0.001037

# %%
final_model.intercept_
# Out:
# 2.9388893694594067

# %% [markdown]
# # **9. Prediction on Final Model**

# %%
adv = [[150, 20, 15]]

# %%
final_model.predict(adv)
# Out:
# array([13.55862413])
